# %%
import numpy as np
import pandas as pd

# %%
whr2015 = pd.read_csv("/Users/moisternw/Desktop/DSSProject/world-happiness-report/2015.csv")

# %%
whr2016 = pd.read_csv("/Users/moisternw/Desktop/DSSProject/world-happiness-report/2016.csv")

# %%
whr2017 = pd.read_csv("/Users/moisternw/Desktop/DSSProject/world-happiness-report/2017.csv")

# %%
energystats = pd.read_csv("/Users/moisternw/Desktop/DSSProject/international-energy-statistics/all_energy_statistics.csv")

# %%
energystats
# Out:
#         country_or_area                commodity_transaction  year  \
# 0               Austria   Additives and Oxygenates - Exports  1996
# 1               Austria   Additives and Oxygenates - Exports  1995
# 2               Belgium   Additives and Oxygenates - Exports  2014
# 3               Belgium   Additives and Oxygenates - Exports  2013
# 4               Belgium   Additives and Oxygenates - Exports  2012
# 5               Belgium   Additives and Oxygenates - Exports  2011
# 6               Belgium   Additives and Oxygenates - Exports  2010
# 7               Belgium   Additives and Oxygenates - Exports  2009
# 8               Czechia   Additives and Oxygenates - Exports  1998
# 9               Czechia   Additives and Oxygenates - Exports  1995
# 10              Finland   Additives and Oxygenates - Exports  2010
# 11              Finland   Additives and Oxygenates - Exports  2009
# 12              Finland   Additives and Oxygenates - Exports  2008
# ...
